# %%
import requests

# %%
URL = "https://www.mlit.go.jp/road/ir/ir-data/census_visualizationR3/webmap.html"
page = requests.get(URL)

print(page.text)
# Out:
# <!doctype html>
# <html>
# <head>
# <meta charset=UTF-8>
# <meta name=viewport content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no"/>
# <title>ä»¤å3å¹´åº¦ ä¸è¬äº¤ééèª¿æ»çµæï¼å¯è¦åãã¼ã«ï¼</title>
# <link rel=stylesheet href="https://unpkg.com/leaflet@0.7.3/dist/leaflet.css"/>
# <link rel=stylesheet href="https://code.jquery.com/ui/1.9.2/themes/base/jquery-ui.css"/>
# <script src="https://unpkg.com/leaflet@0.7.3/dist/leaflet.js"></script>
# <script src="https://code.jquery.com/jquery-2.1.1.min.js"></script>
# <script src="https://code.jquery.com/ui/1.9.2/jquery-ui.js"></script>
# <script src="./TileLayer.GeoJSON.js"></script>
# <script src="./leaflet-hash.js"></script>
# <script src="./property.js"></script>
# <style>
# body {padding: 0; margin: 0;}
# html, body, #mapdiv {height: 100%; width: 100%; font-size:small;}
# #json_dlg, #search_dlg {font-size:small;}
# .leaflet-control {opacity: 0.93}
# .leaflet-container {background: #fff;}
# .leaflet-container .leaflet-control-attribution {font-size: 18px;} /* æä½ããã¥ã¢ã«èªå°æå­åãµã¤ãº */
# .gsi-div-icon {
#   background: none;
#   white-space: nowrap;
#   border:none;
# }
# .ui-dialog {
#   background:white;
# /* 20231016 higa å±æ§ãã¤ã¢ã­ã°ã®éééåº¦
# /*  opacity: 0.93;ï¼åå¤0.93ï¼
# */
#   opacity: 0.97;
# }
# .ui-dialog-titlebar {
#   color:black;
#   background:lightblue;
#   padding: 0.1rem !important;
# /*  font-size: 0.8rem;
# */
#   font-size: 1.2rem;
# }
# .ui-dialog-titlebar-close {
#   color:black;
# }
# .ui-widget-content .ui-state-default{
#   color:black;
#   background:gainsboro;
# }
# .ui-widget-content .ui-state-hover{
#   color:black;
#   background:paleturquoise;
# }
# /* å¡ä¾ */
# .info {
#   padding: 10px 10px;
#   background: white;
#   border-radius: 5px;
#   border: solid;
#   border-width: 1px;
#   border-color: #ddd;
#   box-shadow: 2px 2px 2px rgba(0,0,0,0.2);
# }
# .legend-item {
#   display: flex;
#   align-items: center;
#   color: #555;
# }
# .legend-item-color {
#   display: block;
#   width: 60px;
#   height: 4px;
#   margin-right: 10px;
# }
#
# /* ã»ãã¬ã¼ã¿ 20231016 higa
# .leaflet-control-layers-separator {
#   height: 0;
#   border-top: 1px solid #ddd;
#   margin: 5px -10px 5px -6px;
# }
# */
# .leaflet-control-layers-separator2 {
#   height: 0;
#   border-top: 1px solid #ddd;
#   margin: 5px -10px 27px -6px;
# }
# .leaflet-control-layers-separator3 {
#   height: 0;
#   border-top: 1px solid #fff;
#   margin: 5px -10px 5px -6px;
# }
#
# /* æ¤ç´¢ãã¿ã³ */
# .btn-container {
#   position:absolute;
#   opacity: 0.9;
#   box-shadow: 2px 2px 2px rgba(0,0,0,0.2);
#   z-index: 1000;
# }
# .btn-1 {
#   right:290px;
#   bottom:6px;
# }
#
# /* æ¤ç´¢ãã¤ã¢ã­ã°ã®ä¸å´ãã¿ã³ */
# .ui-button-text {
#   font-size:11px;
# }
#
# </style>
# </head>
# <body>
# <div id=mapdiv></div>
# <div id=json_dlg></div>
# <div id=search_dlg></div>
# <div class="btn-container btn-1"><input type=button id=btn1 onclick="SearchBtn();" value="åºéæ¤ç´¢ã¯ãã¡ã" style="font-size:20px;"/></div>
# <script>
#
# //ã·ã¹ãã ãã­ããã£çæ
# var PROP = new Property();
#
# //âââââââââââââââââââââââââââââââââââââââââââââââââ
# //  æç»ãªãã¸ã§ã¯ãã®ã¬ã¤ã¤çæãmapã¸ã®ã¬ã¤ã¤ç»é²ãã¬ã¤ã¤ã³ã³ãã­ã¼ã«å®ç¾©
# //âââââââââââââââââââââââââââââââââââââââââââââââââ
# //ã¯ãªãã¯ç¨ã¹ã¿ã¤ã«ãªãã·ã§ã³
# var click_style = {
#   options:
#   {
#     minZoom: 12,maxNativeZoom: 13, maxZoom: 18
#   },
#   geojsonOptions:
#   {
#     style: {
#       color:"#000000", weight:PROP.CLICK_TOLERANCE, opacity:0.0, lineCap:"butt"
#     },
#     onEachFeature: function (feature, layer) {
#       layer.on('click', function(e) { CensusDo(feature.properties['census']); });
#       layer.on('mouseover', function(e) {
#         if(feature.geometry.type == "MultiLineString") {
#           e.layer.setStyle({ color:PROP.MOUSEOVER_COLOR, weight:PROP.MOUSEOVER_WEIGHT, opacity:PROP.MOUSEOVER_OPACITY, lineCap:"butt" });
#         }
#         else if(feature.geometry.type == "LineString") {
#           e.target.setStyle({ color:PROP.MOUSEOVER_COLOR, weight:PROP.MOUSEOVER_WEIGHT, opacity:PROP.MOUSEOVER_OPACITY, lineCap:"butt" });
#         }
#       });
#       layer.on('mouseout', function(e) {
#         if(feature.geometry.type == "MultiLineString") {
#           e.layer.setStyle({ color:"#000000", weight:PROP.CLICK_TOLERANCE, opacity:0.0, lineCap:"butt" });
#         }
#         else if(feature.geometry.type == "LineString") {
#           e.target.setStyle({ color:"#000000", weight:PROP.CLICK_TOLERANCE, opacity:0.0, lineCap:"butt" });
#         }
#       });
#     }
#   }
# };
#
# //ã»ã³ãµã¹æç»ç¨ã¹ã¿ã¤ã«ãªãã·ã§ã³
# var styleDRM = {
#   options:
#   {
#     minZoom: 12,maxNativeZoom: 13, maxZoom: 18
#   },
#   geojsonOptions:
#   {
#     style: function (feature) {
#       if(feature.properties['color'] == "10"){ return {color:PROP.DRM10_COLOR, weight:PROP.DRM10_WEIGHT, opacity:PROP.DRM10_OPACITY, lineCap:"butt"}; }
#       else if(feature.properties['color'] == "20"){ return {color:PROP.DRM20_COLOR, weight:PROP.DRM20_WEIGHT, opacity:PROP.DRM20_OPACITY, lineCap:"butt"}; }
#       else if(feature.properties['color'] == "31"){ return {color:PROP.DRM31_COLOR, weight:PROP.DRM31_WEIGHT, opacity:PROP.DRM31_OPACITY, lineCap:"butt"}; }
#       else if(feature.properties['color'] == "32"){ return {color:PROP.DRM32_COLOR, weight:PROP.DRM32_WEIGHT, opacity:PROP.DRM32_OPACITY, lineCap:"butt"}; }
#       else if(feature.properties['color'] == "40"){ return {color:PROP.DRM40_50_COLOR, weight:PROP.DRM40_50_WEIGHT, opacity:PROP.DRM40_50_OPACITY, lineCap:"butt"}; }
#       else if(feature.properties['color'] == "50"){ return {color:PROP.DRM40_50_COLOR, weight:PROP.DRM40_50_WEIGHT, opacity:PROP.DRM40_50_OPACITY, lineCap:"butt"}; }
#       else if(feature.properties['color'] == "60"){ return {color:PROP.DRM60_70_COLOR, weight:PROP.DRM60_70_WEIGHT, opacity:PROP.DRM60_70_OPACITY, lineCap:"butt"}; }
#       else if(feature.properties['color'] == "70"){ return {color:PROP.DRM60_70_COLOR, weight:PROP.DRM60_70_WEIGHT, opacity:PROP.DRM60_70_OPACITY, lineCap:"butt"}; }
#       else{ return {color:"#aaaaaa",weight:0,opacity:0.0,lineCap:"butt"}; }
#     },
#     onEachFeature: function (feature, layer) {
#       layer.on('click', function(e) { CensusDo(feature.properties['census']); });
#     }
#   }
# };
#
# //ã»ã³ãµã¹æç»ã©ã³ã¯åé¢ç¨ã¹ã¿ã¤ã«ãªãã·ã§ã³
# var styleRNK1 = {
#   options:
#   {
#     minZoom: 12,maxNativeZoom: 13, maxZoom: 18
#   },
#   geojsonOptions:
#   {
#     style: function (feature) {
#       var val = feature.properties['Linenum'];
# //console.log("Linenum = " , val)
#       if    (val >= PROP.RANK1_1_VAL1 && val <= PROP.RANK1_1_VAL2 ) { return {color:PROP.RANK1_1_COLOR, weight:PROP.RANK1_1_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK1_2_VAL1 && val <= PROP.RANK1_2_VAL2 ) { return {color:PROP.RANK1_2_COLOR, weight:PROP.RANK1_2_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK1_3_VAL1 && val <= PROP.RANK1_3_VAL2 ) { return {color:PROP.RANK1_3_COLOR, weight:PROP.RANK1_3_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK1_4_VAL1 && val <= PROP.RANK1_4_VAL2 ) { return {color:PROP.RANK1_4_COLOR, weight:PROP.RANK1_4_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK1_5_VAL1 && val <= PROP.RANK1_5_VAL2 ) { return {color:PROP.RANK1_5_COLOR, weight:PROP.RANK1_5_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else { return {color:"#aaaaaa", weight:2, opacity:0, lineCap:"butt"}; }
#     },
#     onEachFeature: function (feature, layer) {
#       layer.on('click', function(e) { CensusDo(feature.properties['census']); });
#     }
#   }
# };
#
# var styleRNK2 = {
#   options:
#   {
#     minZoom: 12,maxNativeZoom: 13, maxZoom: 18
#   },
#   geojsonOptions:
#   {
#     style: function (feature) {
#
#       var val = feature.properties['12H_trf'];
# //console.log("12H_trf = " , val)
#       if     (val > PROP.RANK2_1_VAL1 && val <= PROP.RANK2_1_VAL2 ) { return {color:PROP.RANK2_1_COLOR, weight:PROP.RANK2_1_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK2_2_VAL1 && val <= PROP.RANK2_2_VAL2 ) { return {color:PROP.RANK2_2_COLOR, weight:PROP.RANK2_2_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK2_3_VAL1 && val <= PROP.RANK2_3_VAL2 ) { return {color:PROP.RANK2_3_COLOR, weight:PROP.RANK2_3_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK2_4_VAL1 && val <= PROP.RANK2_4_VAL2 ) { return {color:PROP.RANK2_4_COLOR, weight:PROP.RANK2_4_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK2_5_VAL1 && val <= PROP.RANK2_5_VAL2 ) { return {color:PROP.RANK2_5_COLOR, weight:PROP.RANK2_5_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK2_6_VAL1)                              { return {color:PROP.RANK2_6_COLOR, weight:PROP.RANK2_6_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else { return {color:"#aaaaaa", weight:2, opacity:0, lineCap:"butt"}; }
#     },
#     onEachFeature: function (feature, layer) {
#       layer.on('click', function(e) { CensusDo(feature.properties['census']); });
#     }
#   }
# };
#
# var styleRNK3 = {
#   options:
#   {
#     minZoom: 12,maxNativeZoom: 13, maxZoom: 18
#   },
#   geojsonOptions:
#   {
#     style: function (feature) {
#       var val = feature.properties['24H_trf'];
# //console.log("24H_trf = " , val)
#       if     (val > PROP.RANK3_1_VAL1 && val <= PROP.RANK3_1_VAL2 ) { return {color:PROP.RANK3_1_COLOR, weight:PROP.RANK3_1_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK3_2_VAL1 && val <= PROP.RANK3_2_VAL2 ) { return {color:PROP.RANK3_2_COLOR, weight:PROP.RANK3_2_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK3_3_VAL1 && val <= PROP.RANK3_3_VAL2 ) { return {color:PROP.RANK3_3_COLOR, weight:PROP.RANK3_3_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK3_4_VAL1 && val <= PROP.RANK3_4_VAL2 ) { return {color:PROP.RANK3_4_COLOR, weight:PROP.RANK3_4_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK3_5_VAL1 && val <= PROP.RANK3_5_VAL2 ) { return {color:PROP.RANK3_5_COLOR, weight:PROP.RANK3_5_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK3_6_VAL1)                              { return {color:PROP.RANK3_6_COLOR, weight:PROP.RANK3_6_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else { return {color:"#aaaaaa", weight:2, opacity:0, lineCap:"butt"}; }
#     },
#     onEachFeature: function (feature, layer) {
#       layer.on('click', function(e) { CensusDo(feature.properties['census']); });
#     }
#   }
# };
#
# var styleRNK4 = {
#   options:
#   {
#     minZoom: 12,maxNativeZoom: 13, maxZoom: 18
#   },
#   geojsonOptions:
#   {
#     style: function (feature) {
#       var val = feature.properties['konz'];
# //console.log("konz = " , val);
#       if    (val >= PROP.RANK4_1_VAL1 && val <= PROP.RANK4_1_VAL2 ) { return {color:PROP.RANK4_1_COLOR, weight:PROP.RANK4_1_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK4_2_VAL1 && val <= PROP.RANK4_2_VAL2 ) { return {color:PROP.RANK4_2_COLOR, weight:PROP.RANK4_2_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK4_3_VAL1 && val <= PROP.RANK4_3_VAL2 ) { return {color:PROP.RANK4_3_COLOR, weight:PROP.RANK4_3_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK4_4_VAL1 && val <= PROP.RANK4_4_VAL2 ) { return {color:PROP.RANK4_4_COLOR, weight:PROP.RANK4_4_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK4_5_VAL1 && val <= PROP.RANK4_5_VAL2 ) { return {color:PROP.RANK4_5_COLOR, weight:PROP.RANK4_5_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK4_6_VAL1)                              { return {color:PROP.RANK4_6_COLOR, weight:PROP.RANK4_6_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else { return {color:"#aaaaaa", weight:2, opacity:0, lineCap:"butt"}; }
#     },
#     onEachFeature: function (feature, layer) {
#       layer.on('click', function(e) { CensusDo(feature.properties['census']); });
#     }
#   }
# };
#
#
# var styleRNK5 = {
#   options:
#   {
#     minZoom: 12,maxNativeZoom: 13, maxZoom: 18
#   },
#   geojsonOptions:
#   {
#     style: function (feature) {
#       var val = feature.properties['speed_ME'];
# //console.log("speed_ME = " , val);
#       if     (val > PROP.RANK5_1_VAL1 && val <= PROP.RANK5_1_VAL2 ) { return {color:PROP.RANK5_1_COLOR, weight:PROP.RANK5_1_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK5_2_VAL1 && val <= PROP.RANK5_2_VAL2 ) { return {color:PROP.RANK5_2_COLOR, weight:PROP.RANK5_2_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK5_3_VAL1 && val <= PROP.RANK5_3_VAL2 ) { return {color:PROP.RANK5_3_COLOR, weight:PROP.RANK5_3_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK5_4_VAL1 && val <= PROP.RANK5_4_VAL2 ) { return {color:PROP.RANK5_4_COLOR, weight:PROP.RANK5_4_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK5_5_VAL1 && val <= PROP.RANK5_5_VAL2 ) { return {color:PROP.RANK5_5_COLOR, weight:PROP.RANK5_5_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK5_6_VAL1)                              { return {color:PROP.RANK5_6_COLOR, weight:PROP.RANK5_6_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else { return {color:"#aaaaaa", weight:2, opacity:0, lineCap:"butt"}; }
#     },
#     onEachFeature: function (feature, layer) {
#       layer.on('click', function(e) { CensusDo(feature.properties['census']); });
#     }
#   }
# };
#
# var styleRNK6 = {
#   options:
#   {
#     minZoom: 12,maxNativeZoom: 13, maxZoom: 18
#   },
#   geojsonOptions:
#   {
#     style: function (feature) {
#       var val = feature.properties['speed_DT'];
# //console.log("speed_DT = " , val);
#       if     (val > PROP.RANK6_1_VAL1 && val <= PROP.RANK6_1_VAL2 ) { return {color:PROP.RANK6_1_COLOR, weight:PROP.RANK6_1_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK6_2_VAL1 && val <= PROP.RANK6_2_VAL2 ) { return {color:PROP.RANK6_2_COLOR, weight:PROP.RANK6_2_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK6_3_VAL1 && val <= PROP.RANK6_3_VAL2 ) { return {color:PROP.RANK6_3_COLOR, weight:PROP.RANK6_3_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK6_4_VAL1 && val <= PROP.RANK6_4_VAL2 ) { return {color:PROP.RANK6_4_COLOR, weight:PROP.RANK6_4_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK6_5_VAL1 && val <= PROP.RANK6_5_VAL2 ) { return {color:PROP.RANK6_5_COLOR, weight:PROP.RANK6_5_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else if(val > PROP.RANK6_6_VAL1)                              { return {color:PROP.RANK6_6_COLOR, weight:PROP.RANK6_6_WEIGHT, opacity:1, lineCap:"butt"}; }
#       else { return {color:"#aaaaaa", weight:2, opacity:0, lineCap:"butt"}; }
#     },
#     onEachFeature: function (feature, layer) {
#       layer.on('click', function(e) { CensusDo(feature.properties['census']); });
#     }
#   }
# };
#
#
# //DRMãªãã¸ã§ã¯ãçæ
# var layerDRM10_A1 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', styleDRM.options, styleDRM.geojsonOptions);
# var layerDRM20_A1 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', styleDRM.options, styleDRM.geojsonOptions);
# var layerDRM31_A1 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', styleDRM.options, styleDRM.geojsonOptions);
# var layerDRM32_A1 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', styleDRM.options, styleDRM.geojsonOptions);
# var layerDRM40_50_A1 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', styleDRM.options, styleDRM.geojsonOptions);
# var layerDRM60_70_A1 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', styleDRM.options, styleDRM.geojsonOptions);
#
# var layerDRM10_A2 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM20_A2 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM31_A2 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM32_A2 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM40_50_A2 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM60_70_A2 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
#
# //DRMã©ã³ã¯ãªãã¸ã§ã¯ãçæ
# var layerDRM10_B1 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', styleRNK1.options, styleRNK1.geojsonOptions);
# var layerDRM20_B1 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', styleRNK1.options, styleRNK1.geojsonOptions);
# var layerDRM31_B1 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', styleRNK1.options, styleRNK1.geojsonOptions);
# var layerDRM32_B1 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', styleRNK1.options, styleRNK1.geojsonOptions);
# var layerDRM40_50_B1 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', styleRNK1.options, styleRNK1.geojsonOptions);
# var layerDRM60_70_B1 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', styleRNK1.options, styleRNK1.geojsonOptions);
#
# var layerDRM10_B2 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM20_B2 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM31_B2 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM32_B2 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM40_50_B2 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM60_70_B2 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
#
# var layerDRM10_C1 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', styleRNK2.options, styleRNK2.geojsonOptions);
# var layerDRM20_C1 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', styleRNK2.options, styleRNK2.geojsonOptions);
# var layerDRM31_C1 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', styleRNK2.options, styleRNK2.geojsonOptions);
# var layerDRM32_C1 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', styleRNK2.options, styleRNK2.geojsonOptions);
# var layerDRM40_50_C1 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', styleRNK2.options, styleRNK2.geojsonOptions);
# var layerDRM60_70_C1 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', styleRNK2.options, styleRNK2.geojsonOptions);
#
# var layerDRM10_C2 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM20_C2 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM31_C2 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM32_C2 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM40_50_C2 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM60_70_C2 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
#
# var layerDRM10_D1 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', styleRNK3.options, styleRNK3.geojsonOptions);
# var layerDRM20_D1 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', styleRNK3.options, styleRNK3.geojsonOptions);
# var layerDRM31_D1 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', styleRNK3.options, styleRNK3.geojsonOptions);
# var layerDRM32_D1 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', styleRNK3.options, styleRNK3.geojsonOptions);
# var layerDRM40_50_D1 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', styleRNK3.options, styleRNK3.geojsonOptions);
# var layerDRM60_70_D1 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', styleRNK3.options, styleRNK3.geojsonOptions);
#
# var layerDRM10_D2 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM20_D2 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM31_D2 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM32_D2 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM40_50_D2 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM60_70_D2 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
#
# var layerDRM10_E1 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', styleRNK4.options, styleRNK4.geojsonOptions);
# var layerDRM20_E1 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', styleRNK4.options, styleRNK4.geojsonOptions);
# var layerDRM31_E1 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', styleRNK4.options, styleRNK4.geojsonOptions);
# var layerDRM32_E1 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', styleRNK4.options, styleRNK4.geojsonOptions);
# var layerDRM40_50_E1 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', styleRNK4.options, styleRNK4.geojsonOptions);
# var layerDRM60_70_E1 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', styleRNK4.options, styleRNK4.geojsonOptions);
#
# var layerDRM10_E2 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM20_E2 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM31_E2 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM32_E2 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM40_50_E2 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM60_70_E2 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
#
# var layerDRM10_F1 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', styleRNK5.options, styleRNK5.geojsonOptions);
# var layerDRM20_F1 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', styleRNK5.options, styleRNK5.geojsonOptions);
# var layerDRM31_F1 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', styleRNK5.options, styleRNK5.geojsonOptions);
# var layerDRM32_F1 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', styleRNK5.options, styleRNK5.geojsonOptions);
# var layerDRM40_50_F1 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', styleRNK5.options, styleRNK5.geojsonOptions);
# var layerDRM60_70_F1 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', styleRNK5.options, styleRNK5.geojsonOptions);
#
# var layerDRM10_F2 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM20_F2 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM31_F2 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM32_F2 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM40_50_F2 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM60_70_F2 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
#
# var layerDRM10_G1 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', styleRNK6.options, styleRNK6.geojsonOptions);
# var layerDRM20_G1 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', styleRNK6.options, styleRNK6.geojsonOptions);
# var layerDRM31_G1 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', styleRNK6.options, styleRNK6.geojsonOptions);
# var layerDRM32_G1 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', styleRNK6.options, styleRNK6.geojsonOptions);
# var layerDRM40_50_G1 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', styleRNK6.options, styleRNK6.geojsonOptions);
# var layerDRM60_70_G1 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', styleRNK6.options, styleRNK6.geojsonOptions);
#
# var layerDRM10_G2 = new L.TileLayer.GeoJSON('./drm10/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM20_G2 = new L.TileLayer.GeoJSON('./drm20/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM31_G2 = new L.TileLayer.GeoJSON('./drm31/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM32_G2 = new L.TileLayer.GeoJSON('./drm32/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM40_50_G2 = new L.TileLayer.GeoJSON('./drm40_50/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
# var layerDRM60_70_G2 = new L.TileLayer.GeoJSON('./drm60_70/{z}/{x}/{y}.geojson', click_style.options, click_style.geojsonOptions);
#
#
# //ã°ã«ã¼ããªãã¸ã§ã¯ãçæ
# var layerDRM10 = L.layerGroup([layerDRM10_A1, layerDRM10_A2]); //.addTo(map);
# var layerDRM20 = L.layerGroup([layerDRM20_A1, layerDRM20_A2]); //.addTo(map);
# var layerDRM31 = L.layerGroup([layerDRM31_A1, layerDRM31_A2]); //.addTo(map);
# var layerDRM32 = L.layerGroup([layerDRM32_A1, layerDRM32_A2]); //.addTo(map);
# var layerDRM40_50 = L.layerGroup([layerDRM40_50_A1, layerDRM40_50_A2]); //.addTo(map);
# var layerDRM60_70 = L.layerGroup([layerDRM60_70_A1, layerDRM60_70_A2]); //.addTo(map);
#
# //ã©ã³ã¯ã¢ã¼ãç¨ã®ããã¼ã¬ã¤ã¤
# /* é«ééï¼å½éï¼å°æ¹éï¼ä¸è¬éã®é 
# var layerRNK1 = L.layerGroup([layerDRM10_B1, layerDRM20_B1, layerDRM31_B1, layerDRM32_B1, layerDRM40_50_B1, layerDRM60_70_B1, layerDRM10_B2, layerDRM20_B2, layerDRM31_B2, layerDRM32_B2, layerDRM40_50_B2, layerDRM60_70_B2]);
# var layerRNK2 = L.layerGroup([layerDRM10_C1, layerDRM20_C1, layerDRM31_C1, layerDRM32_C1, layerDRM40_50_C1, layerDRM60_70_C1, layerDRM10_C2, layerDRM20_C2, layerDRM31_C2, layerDRM32_C2, layerDRM40_50_C2, layerDRM60_70_C2]);
# var layerRNK3 = L.layerGroup([layerDRM10_D1, layerDRM20_D1, layerDRM31_D1, layerDRM32_D1, layerDRM40_50_D1, layerDRM60_70_D1, layerDRM10_D2, layerDRM20_D2, layerDRM31_D2, layerDRM32_D2, layerDRM40_50_D2, layerDRM60_70_D2]);
# var layerRNK4 = L.layerGroup([layerDRM10_E1, layerDRM20_E1, layerDRM31_E1, layerDRM32_E1, layerDRM40_50_E1, layerDRM60_70_E1, layerDRM10_E2, layerDRM20_E2, layerDRM31_E2, layerDRM32_E2, layerDRM40_50_E2, layerDRM60_70_E2]);
# var layerRNK5 = L.layerGroup([layerDRM10_F1, layerDRM20_F1, layerDRM31_F1, layerDRM32_F1, layerDRM40_50_F1, layerDRM60_70_F1, layerDRM10_F2, layerDRM20_F2, layerDRM31_F2, layerDRM32_F2, layerDRM40_50_F2, layerDRM60_70_F2]);
# var layerRNK6 = L.layerGroup([layerDRM10_G1, layerDRM20_G1, layerDRM31_G1, layerDRM32_G1, layerDRM40_50_G1, layerDRM60_70_G1, layerDRM10_G2, layerDRM20_G2, layerDRM31_G2, layerDRM32_G2, layerDRM40_50_G2, layerDRM60_70_G2]);
# */
# /* ä¸è¬éï¼å°æ¹éï¼å½éï¼é«ééã®é  */
# var layerRNK1 = L.layerGroup([layerDRM60_70_B1, layerDRM40_50_B1, layerDRM32_B1, layerDRM31_B1, layerDRM20_B1, layerDRM10_B1, layerDRM60_70_B2, layerDRM40_50_B2, layerDRM32_B2, layerDRM31_B2, layerDRM20_B2, layerDRM10_B2]);
# var layerRNK2 = L.layerGroup([layerDRM60_70_C1, layerDRM40_50_C1, layerDRM32_C1, layerDRM31_C1, layerDRM20_C1, layerDRM10_C1, layerDRM60_70_C2, layerDRM40_50_C2, layerDRM32_C2, layerDRM31_C2, layerDRM20_C2, layerDRM10_C2]);
# var layerRNK3 = L.layerGroup([layerDRM60_70_D1, layerDRM40_50_D1, layerDRM32_D1, layerDRM31_D1, layerDRM20_D1, layerDRM10_D1, layerDRM60_70_D2, layerDRM40_50_D2, layerDRM32_D2, layerDRM31_D2, layerDRM20_D2, layerDRM10_D2]);
# var layerRNK4 = L.layerGroup([layerDRM60_70_E1, layerDRM40_50_E1, layerDRM32_E1, layerDRM31_E1, layerDRM20_E1, layerDRM10_E1, layerDRM60_70_E2, layerDRM40_50_E2, layerDRM32_E2, layerDRM31_E2, layerDRM20_E2, layerDRM10_E2]);
# var layerRNK5 = L.layerGroup([layerDRM60_70_F1, layerDRM40_50_F1, layerDRM32_F1, layerDRM31_F1, layerDRM20_F1, layerDRM10_F1, layerDRM60_70_F2, layerDRM40_50_F2, layerDRM32_F2, layerDRM31_F2, layerDRM20_F2, layerDRM10_F2]);
# var layerRNK6 = L.layerGroup([layerDRM60_70_G1, layerDRM40_50_G1, layerDRM32_G1, layerDRM31_G1, layerDRM20_G1, layerDRM10_G1, layerDRM60_70_G2, layerDRM40_50_G2, layerDRM32_G2, layerDRM31_G2, layerDRM20_G2, layerDRM10_G2]);
#
# //éè¦ç©æµéè·¯ãªãã¸ã§ã¯ãçæ
# var styleLOG1 = {
#   options:
#   { minZoom: 10,maxNativeZoom: 13, maxZoom: 18 },
#   geojsonOptions:
#   {
#     style: function (feature) {
#       if(feature.properties['logistics'] == "1"){ return {color:PROP.LOG1_COLOR, weight:PROP.LOG1_WEIGHT, opacity:PROP.LOG1_OPACITY, lineCap:"butt"}; }
#       else{ return {color:"#000000",weight:0,opacity:0.0,lineCap:"butt"}; }
#     }
#   }
# };
# var styleLOG2 = {
#   options:
#   { minZoom: 10,maxNativeZoom: 13, maxZoom: 18 },
#   geojsonOptions:
#   {
#     style: function (feature) {
#       if(feature.properties['siteikukan'] == "1"){ return {color:PROP.LOG2_COLOR, weight:PROP.LOG2_WEIGHT, opacity:PROP.LOG2_OPACITY, lineCap:"butt"}; }
#       else{ return {color:"#000000",weight:0,opacity:0.0,lineCap:"butt"}; }
#     }
#   }
# };
# var styleLOG3 = {
#   options:
#   { minZoom: 10,maxNativeZoom: 13, maxZoom: 18 },
#   geojsonOptions:
#   {
#     style: function (feature) {
#       if(feature.properties['logistics'] == "2"){ return {color:PROP.LOG3_COLOR, weight:PROP.LOG3_WEIGHT, opacity:PROP.LOG3_OPACITY, lineCap:"butt"}; }
#       else{ return {color:"#000000",weight:0,opacity:0.0,lineCap:"butt"}; }
#     }
#   }
# };
# var layerLOG1 = new L.TileLayer.GeoJSON('./butsuryu/03DZ/{z}/{x}/{y}.geojson', styleLOG1.options, styleLOG1.geojsonOptions);
# var layerLOG2 = new L.TileLayer.GeoJSON('./butsuryu/03DZ/{z}/{x}/{y}.geojson', styleLOG2.options, styleLOG2.geojsonOptions);
# var layerLOG3 = new L.TileLayer.GeoJSON('./butsuryu/03DZ/{z}/{x}/{y}.geojson', styleLOG3.options, styleLOG3.geojsonOptions);
#
# //ä¸»è¦æ¸æ»ç®æãªãã¸ã§ã¯ãçæ
# var xhr = new XMLHttpRequest();
# xhr.open('GET', './syuyouzyutai/stylePB.js', false);
# xhr.send(null);
# var stylejs2 = eval( "(" + xhr.responseText + ")" );
# var layerJAM = new L.TileLayer.GeoJSON('./syuyouzyutai/{z}/{x}/{y}.geojson', stylejs2.options, stylejs2.geojsonOptions);
#
# //ä¸å³ãªãã¸ã§ã¯ãçæ
# var manual_ref = "<a href='./R3_Visualizationtool_manual.pdf' target='_blank'>æä½ããã¥ã¢ã«ã¯ãã¡ã</a>";
# var std = L.tileLayer('https://cyberjapandata.gsi.go.jp/xyz/std/{z}/{x}/{y}.png', {attribution: manual_ref, maxNativeZoom: 18, maxZoom: 18, opacity:1});
# var pale = L.tileLayer('https://cyberjapandata.gsi.go.jp/xyz/pale/{z}/{x}/{y}.png',{attribution: manual_ref, maxNativeZoom: 18, maxZoom: 18, opacity:1});
# var ort = L.tileLayer('https://cyberjapandata.gsi.go.jp/xyz/ort/{z}/{x}/{y}.jpg',{attribution: manual_ref, maxNativeZoom: 17, maxZoom: 18, opacity:1});
# var blank = L.tileLayer('https://cyberjapandata.gsi.go.jp/xyz/blank/{z}/{x}/{y}.png',{attribution: manual_ref, maxNativeZoom: 14, maxZoom: 18, opacity:1});
#
# //ãªãã¸ã§ã¯ãæç»
# var map = L.map('mapdiv', {
# //  attributionControl:manual_ref,
# //  attribution:manual_ref,
#   preferCanvas: true,
#   zoomControl: false,
# //center: [26.504293, 127.950804], zoom: 13,minZoom: 8, maxZoom: 18, //æ²ç¸
#   center: [43.064310, 141.346879], zoom: 13,minZoom: 8, maxZoom: 18, //åæµ·é
#
#   layers: [layerDRM10, layerDRM20, layerDRM31, layerDRM32, layerDRM40_50, layerDRM60_70, pale]});     //åããé çªã«ãªã¼ãã¬ã¤ããã
#
# // æ²ç¸ã26.504293, 127.950804 é¢æ±ã35.682256, 139.755018 åæµ·éã43.064310, 141.346879
#
# L.control.scale({imperial: false}).addTo(map);
# L.control.zoom({ position: 'bottomleft' }).addTo(map);
#
# //è¡¨ç¤ºåæ¿ã³ã³ãã­ã¼ã«
# var baseLayers = {"å°çé¢ã¿ã¤ã«ï¼æ¨æºå°å³ï¼": std,"å°çé¢ã¿ã¤ã«ï¼æ·¡è²å°å³ï¼": pale,"å°çé¢ã¿ã¤ã«ï¼ãªã«ã½ï¼": ort,"å°çé¢ã¿ã¤ã«ï¼ç½å°å³ï¼": blank};
#
# var roadsDRM10 = '<span style="color:' + PROP.DRM10_COLOR + ';letter-spacing:-2pt">â â â â â â </span>ã' + PROP.DRM10_NAME;
# var roadsDRM20 = '<span style="color:' + PROP.DRM20_COLOR + ';letter-spacing:-2pt">â â â â â â </span>ã' + PROP.DRM20_NAME;
# var roadsDRM31 = '<span style="color:' + PROP.DRM31_COLOR + ';letter-spacing:-2pt">â â â â â â </span>ã' + PROP.DRM31_NAME;
# var roadsDRM32 = '<span style="color:' + PROP.DRM32_COLOR + ';letter-spacing:-2pt">â â â â â â </span>ã' + PROP.DRM32_NAME;
# var roadsDRM40_50 = '<span style="color:' + PROP.DRM40_50_COLOR + ';letter-spacing:-2pt">â â â â â â </span>ã' + PROP.DRM40_50_NAME;
# var roadsDRM60_70 = '<span style="color:' + PROP.DRM60_70_COLOR + ';letter-spacing:-2pt">â â â â â â </span>ã' + PROP.DRM60_70_NAME
#                     +'<br><br>----------ï¼ãèª¿æ»çµæï¼éå±¤åºåå³ï¼ãï¼----------';
# //                    +'<div class="leaflet-control-layers-separator2"><div>'+'<div class="leaflet-control-layers-separator3"><div>ããã©ã³ã¯å³ ï¼éç´è¡¨ç¤ºï¼'; //20231016 higa
#
# var roadsRNK1 = PROP.RANK1_NAME;
# var roadsRNK2 = PROP.RANK2_NAME;
# var roadsRNK3 = PROP.RANK3_NAME;
# var roadsRNK4 = PROP.RANK4_NAME;
# var roadsRNK5 = PROP.RANK5_NAME;
# var roadsRNK6 = PROP.RANK6_NAME
#                     +'<br><br>----------ï¼ä¸è¬äº¤ééèª¿æ»ä»¥å¤ã®æå ±ï¼----------';
# //                    +'<div class="leaflet-control-layers-separator2"><div>'+'<div class="leaflet-control-layers-separator3"><div>ããä¸è¬äº¤ééèª¿æ»ä»¥å¤ã®æå ±'; //20231016 higa
#
# var roadsLOG1 = '<font color="' + PROP.LOG1_COLOR + '">ââ</font>ã' + PROP.LOG1_NAME;
# var roadsLOG2 = PROP.LOG2_NAME;
# var roadsLOG3 = '<font color="' + PROP.LOG3_COLOR + '">ââ</font>ã' + PROP.LOG3_NAME;
# var pointJAM = '<img src="./syuyouzyutai/marker-iconPinkB6.png" width="10" height="10">ã' + PROP.JAM_NAME;
#
# var overlays = {};
# overlays[roadsDRM10] = layerDRM10;
# overlays[roadsDRM20] = layerDRM20;
# overlays[roadsDRM31] = layerDRM31;
# overlays[roadsDRM32] = layerDRM32;
# overlays[roadsDRM40_50] = layerDRM40_50;
# overlays[roadsDRM60_70] = layerDRM60_70;
# overlays[roadsRNK1] = layerRNK1;
# overlays[roadsRNK2] = layerRNK2;
# overlays[roadsRNK3] = layerRNK3;
# overlays[roadsRNK4] = layerRNK4;
# overlays[roadsRNK5] = layerRNK5;
# overlays[roadsRNK6] = layerRNK6;
# overlays[roadsLOG1] = layerLOG1;
# overlays[roadsLOG2] = layerLOG2;
# overlays[roadsLOG3] = layerLOG3;
# overlays[pointJAM] = layerJAM;
#
# var layerscontrol = L.control.layers(baseLayers,overlays,{position:'topright',collapsed:false}).addTo(map);
# var rank_mode = 0;
#
# //ã¬ã¤ã¤å¤æ´ã¤ãã³ã
# map.on('layeradd', function (e) {
#   //éè¦ç©æµåã®æä»å¶å¾¡
#   if(e.layer == layerLOG1){
#     if(map.hasLayer(layerLOG2)) {
#       map.removeLayer(layerLOG2);
#       map.removeControl(layerscontrol);
#       layerLOG1.bringToBack();
#       layerscontrol = L.control.layers(baseLayers,overlays,{position:'topright',collapsed:false}).addTo(map);
#     }
#   }
#   else if(e.layer == layerLOG2) {
#     if(map.hasLayer(layerLOG1)) {
#       map.removeLayer(layerLOG1);
#       map.removeControl(layerscontrol);
#       layerLOG2.bringToBack();
#       layerscontrol = L.control.layers(baseLayers,overlays,{position:'topright',collapsed:false}).addTo(map);
#     }
#   }
#   else if(e.layer == layerLOG3){
#     layerLOG3.bringToBack();
#   }
#
#   //ã©ã³ã¯é¸æåå²ï¼ã©ã³ã¯ã®ä½ãããè¡¨ç¤ºé¸æãããã¨ãï¼
#   else if(e.layer == layerRNK1 || e.layer == layerRNK2 || e.layer == layerRNK3 || e.layer == layerRNK4 || e.layer == layerRNK5 || e.layer == layerRNK6){
#     if(rank_mode == 0) {
#       $("#json_dlg").dialog( "close" );
#     }
#     if(CensusLayer != 0) {
#       CensusLayerBringToFront();
#     }
#
#     if(e.layer == layerRNK1)      { rank_mode = 1; legend1.addTo(map); }
#     else if(e.layer == layerRNK2) { rank_mode = 2; legend2.addTo(map); }
#     else if(e.layer == layerRNK3) { rank_mode = 3; legend3.addTo(map); }
#     else if(e.layer == layerRNK4) { rank_mode = 4; legend4.addTo(map); }
#     else if(e.layer == layerRNK5) { rank_mode = 5; legend5.addTo(map); }
#     else if(e.layer == layerRNK6) { rank_mode = 6; legend6.addTo(map); }
#
#     if(map.hasLayer(layerDRM10))    { map.removeLayer(layerDRM10); }
#     if(map.hasLayer(layerDRM20))    { map.removeLayer(layerDRM20); }
#     if(map.hasLayer(layerDRM31))    { map.removeLayer(layerDRM31); }
#     if(map.hasLayer(layerDRM32))    { map.removeLayer(layerDRM32); }
#     if(map.hasLayer(layerDRM40_50)) { map.removeLayer(layerDRM40_50); }
#     if(map.hasLayer(layerDRM60_70)) { map.removeLayer(layerDRM60_70); }
#
#     if(e.layer != layerRNK1) { if(map.hasLayer(layerRNK1)){ map.removeLayer(layerRNK1); }}
#     if(e.layer != layerRNK2) { if(map.hasLayer(layerRNK2)){ map.removeLayer(layerRNK2); }}
#     if(e.layer != layerRNK3) { if(map.hasLayer(layerRNK3)){ map.removeLayer(layerRNK3); }}
#     if(e.layer != layerRNK4) { if(map.hasLayer(layerRNK4)){ map.removeLayer(layerRNK4); }}
#     if(e.layer != layerRNK5) { if(map.hasLayer(layerRNK5)){ map.removeLayer(layerRNK5); }}
#     if(e.layer != layerRNK6) { if(map.hasLayer(layerRNK6)){ map.removeLayer(layerRNK6); }}
#
#     map.removeControl(layerscontrol);
#     layerscontrol = L.control.layers(baseLayers,overlays,{position:'topright',collapsed:false}).addTo(map);
#   }
#
#   //ã©ã³ã¯éé¸æåå²ï¼ã©ã³ã¯è¡¨ç¤ºä¸­ã«éã©ã³ã¯è¡¨ç¤ºé¸æãçºçããã¨ãï¼
#   else if(e.layer == layerDRM10 || e.layer == layerDRM20 || e.layer == layerDRM31 || e.layer == layerDRM32 || e.layer == layerDRM40_50 || e.layer == layerDRM60_70){
#
#     if(rank_mode != 0) {
#       $("#json_dlg").dialog( "close" );
#     }
#
#     if(map.hasLayer(layerRNK1))     { map.removeLayer(layerRNK1); }
#     else if(map.hasLayer(layerRNK2)){ map.removeLayer(layerRNK2); }
#     else if(map.hasLayer(layerRNK3)){ map.removeLayer(layerRNK3); }
#     else if(map.hasLayer(layerRNK4)){ map.removeLayer(layerRNK4); }
#     else if(map.hasLayer(layerRNK5)){ map.removeLayer(layerRNK5); }
#     else if(map.hasLayer(layerRNK6)){ map.removeLayer(layerRNK6); }
#   }
# });
#
# map.on('layerremove', function (e) {
#   if(e.layer == layerRNK1){
#     map.removeControl(legend1);
#     if(rank_mode == 1){
#       RnkFin();
#     }
#   }
#   else if(e.layer == layerRNK2){
#     map.removeControl(legend2);
#     if(rank_mode == 2){
#       RnkFin();
#     }
#   }
#   else if(e.layer == layerRNK3){
#     map.removeControl(legend3);
#     if(rank_mode == 3){
#       RnkFin();
#     }
#   }
#   else if(e.layer == layerRNK4){
#     map.removeControl(legend4);
#     if(rank_mode == 4){
#       RnkFin();
#     }
#   }
#   else if(e.layer == layerRNK5){
#     map.removeControl(legend5);
#     if(rank_mode == 5){
#       RnkFin();
#     }
#   }
#   else if(e.layer == layerRNK6){
#     map.removeControl(legend6);
#     if(rank_mode == 6){
#       RnkFin();
#     }
#   }
# });
#
# function RnkFin() {
#    //ã²ã¨ã¤ãè¡¨ç¤ºããã¦ããªããã°å¨è¡¨ç¤ºï¼åæåï¼
#   if(!map.hasLayer(layerDRM10) && !map.hasLayer(layerDRM20) && !map.hasLayer(layerDRM31) && !map.hasLayer(layerDRM32) && !map.hasLayer(layerDRM40_50) && !map.hasLayer(layerDRM60_70) ){
#     layerDRM10.addTo(map);
#     layerDRM20.addTo(map);
#     layerDRM31.addTo(map);
#     layerDRM32.addTo(map);
#     layerDRM40_50.addTo(map);
#     layerDRM60_70.addTo(map);
#   }
#   map.removeControl(layerscontrol);
#   layerscontrol = L.control.layers(baseLayers,overlays,{position:'topright',collapsed:false}).addTo(map);
#   rank_mode = 0;
# }
#
# //âââââââââââââââââââââââââââââââââââââââââââââââââ
# // å¡ä¾ãå³ä¸ã«è¿½å
# //âââââââââââââââââââââââââââââââââââââââââââââââââ
# var legend1 = L.control({position: 'bottomright'});
#
# legend1.onAdd = function (map) {
#   var div = L.DomUtil.create('div', 'info legend');
#   var htmlTxt = '';
#   htmlTxt = PROP.RANK1_LEGEND; //'<center>è»ç·æ° éç´å¡ä¾</center>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK1_1_COLOR + '"></span> ' + PROP.RANK1_1_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK1_2_COLOR + '"></span> ' + PROP.RANK1_2_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK1_3_COLOR + '"></span> ' + PROP.RANK1_3_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK1_4_COLOR + '"></span> ' + PROP.RANK1_4_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK1_5_COLOR + '"></span> ' + PROP.RANK1_5_NAME + '</span>';
#   div.innerHTML = htmlTxt;
#   return div;
# };
#
# var legend2 = L.control({position: 'bottomright'});
#
# legend2.onAdd = function (map) {
#   var div = L.DomUtil.create('div', 'info legend');
#   var htmlTxt = ''
#   htmlTxt = PROP.RANK2_LEGEND;
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK2_1_COLOR + '"></span> ' + PROP.RANK2_1_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK2_2_COLOR + '"></span> ' + PROP.RANK2_2_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK2_3_COLOR + '"></span> ' + PROP.RANK2_3_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK2_4_COLOR + '"></span> ' + PROP.RANK2_4_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK2_5_COLOR + '"></span> ' + PROP.RANK2_5_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK2_6_COLOR + '"></span> ' + PROP.RANK2_6_NAME + '</span>';
#   div.innerHTML = htmlTxt;
#   return div;
# };
#
# var legend3 = L.control({position: 'bottomright'});
#
# legend3.onAdd = function (map) {
#   var div = L.DomUtil.create('div', 'info legend');
#   var htmlTxt = ''
#   htmlTxt = PROP.RANK3_LEGEND;
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK3_1_COLOR + '"></span> ' + PROP.RANK3_1_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK3_2_COLOR + '"></span> ' + PROP.RANK3_2_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK3_3_COLOR + '"></span> ' + PROP.RANK3_3_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK3_4_COLOR + '"></span> ' + PROP.RANK3_4_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK3_5_COLOR + '"></span> ' + PROP.RANK3_5_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK3_6_COLOR + '"></span> ' + PROP.RANK3_6_NAME + '</span>';
#   div.innerHTML = htmlTxt;
#   return div;
# };
#
# var legend4 = L.control({position: 'bottomright'});
#
# legend4.onAdd = function (map) {
#   var div = L.DomUtil.create('div', 'info legend');
#   var htmlTxt = ''
#   htmlTxt = PROP.RANK4_LEGEND;
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK4_1_COLOR + '"></span> ' + PROP.RANK4_1_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK4_2_COLOR + '"></span> ' + PROP.RANK4_2_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK4_3_COLOR + '"></span> ' + PROP.RANK4_3_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK4_4_COLOR + '"></span> ' + PROP.RANK4_4_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK4_5_COLOR + '"></span> ' + PROP.RANK4_5_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK4_6_COLOR + '"></span> ' + PROP.RANK4_6_NAME + '</span>';
#   div.innerHTML = htmlTxt;
#   return div;
# };
#
#
# var legend5 = L.control({position: 'bottomright'});
#
# legend5.onAdd = function (map) {
#   var div = L.DomUtil.create('div', 'info legend');
#   var htmlTxt = ''
#   htmlTxt = PROP.RANK5_LEGEND;
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK5_1_COLOR + '"></span> ' + PROP.RANK5_1_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK5_2_COLOR + '"></span> ' + PROP.RANK5_2_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK5_3_COLOR + '"></span> ' + PROP.RANK5_3_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK5_4_COLOR + '"></span> ' + PROP.RANK5_4_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK5_5_COLOR + '"></span> ' + PROP.RANK5_5_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK5_6_COLOR + '"></span> ' + PROP.RANK5_6_NAME + '</span>';
#   div.innerHTML = htmlTxt;
#   return div;
# };
#
#
# var legend6 = L.control({position: 'bottomright'});
#
# legend6.onAdd = function (map) {
#   var div = L.DomUtil.create('div', 'info legend');
#   var htmlTxt = ''
#   htmlTxt = PROP.RANK6_LEGEND;
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK6_1_COLOR + '"></span> ' + PROP.RANK6_1_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK6_2_COLOR + '"></span> ' + PROP.RANK6_2_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK6_3_COLOR + '"></span> ' + PROP.RANK6_3_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK6_4_COLOR + '"></span> ' + PROP.RANK6_4_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK6_5_COLOR + '"></span> ' + PROP.RANK6_5_NAME + '</span>';
#   htmlTxt = htmlTxt + '<span class="legend-item"><span class="legend-item-color" style="background:' + PROP.RANK6_6_COLOR + '"></span> ' + PROP.RANK6_6_NAME + '</span>';
#   div.innerHTML = htmlTxt;
#   return div;
# };
#
# //âââââââââââââââââââââââââââââââââââââââââââââââââ
# //  å±æ§è¡¨ç¤ºãé¸æã»ã³ãµã¹ã®ãªã¼ãã¬ã¤è¡¨ç¤º
# //âââââââââââââââââââââââââââââââââââââââââââââââââ
# //#json_dlgå®ç¾©
# var json_dlg = $(function() {
#   $("#json_dlg").dialog({
#     title:"ãåºéå±æ§ã»èª¿æ»çµæ",
#     height: PROP.JSON_DIALOG_H, width: PROP.JSON_DIALOG_W,    //æ²è¼ãã¼ã¿ã®åå®¹å¦ä½ã§èª¿æ´å¿è¦
#     position: { at: 'right top', my: 'right-10 top+10' },
# ...
#   }
#
#   var url = PROP.EXCEL_URL + filename ;
#   var url = PROP.EXCEL_URL + kenpass + filename ;
#   var xhr = new XMLHttpRequest();
#   xhr.open("GET", url, true);
#   xhr.responseType = "blob"; // Blobãªãã¸ã§ã¯ãã¨ãã¦ãã¦ã³ã­ã¼ããã
#   xhr.onload = function (oEvent) {
#     var blob = xhr.response;
#     if (window.navigator.msSaveBlob) {// IEã¨Edge
#       window.navigator.msSaveBlob(blob, filename);
#     } else { // ããä»¥å¤ã®ãã©ã¦ã¶
#       var objectURL = window.URL.createObjectURL(blob);
#       var link = document.createElement("a"); //<a>ãçæãã¦çä¼¼ã¯ãªãã¯
#       document.body.appendChild(link);
#       link.href = objectURL;
#       link.download = filename;
#       link.click();
#       document.body.removeChild(link);
#     }
#   };
#   xhr.send();
# }
#
# //CensusDo ã»ã³ãµã¹ã¯ãªãã¯å¦ç(é¸æåºéã¬ã¤ã¤ï½CensusLayerã®è¿½å ã¨å±æ§ãã¤ã¢ã­ã°è¡¨ç¤º)
# var CensusLayer = 0;
#
# var CensusDo = function(sCnsId, jump = false) {
#   if(CensusLayer != 0) {
#     map.removeLayer(CensusLayer);
#     CensusLayer = 0;
#   }
#
#   JsonDisp(sCnsId);
#
#   var sKen = sCnsId.substr(0, 2);
#   var sFile = './census/' + sKen + '/' + sCnsId + '.geojson';
#   var lat;
#   var lon;
#   $.ajaxSetup({async: false}); //åæå¦çã«åæ¿
#   $.getJSON(sFile, function (data) {
#     var geojson = L.geoJson(data, {
#       style: function (feature) {
#          if(feature.geometry.type == "MultiLineString") {
#            lat = feature.geometry.coordinates[0][0][0];
#            lon = feature.geometry.coordinates[0][0][1];
#          } else {
#            lat = feature.geometry.coordinates[0][0];
#            lon = feature.geometry.coordinates[0][1];
#          }
#          return {color:PROP.SELECT_COLOR, weight:PROP.SELECT_WEIGHT, opacity:PROP.SELECT_OPACITY, lineCap:"butt"};
#       }
#     });
#     CensusLayer = geojson.addTo(map);
#     if(jump) {
#       map.setView([lon, lat]);
#     }
#     CensusLayerBringToFront();
#
#   });
#   $.ajaxSetup({async: true}); //éåæå¦çã«åæ¿
# };
#
# //ãã¤ã¢ã­ã°ãéããããã¨ããé¸æåºéã¬ã¤ã¤(CensusLayer)ãæ¶ã
# $("#json_dlg").bind(
#     "dialogclose",
#     function(e) {
#       if(CensusLayer != 0) {
#         map.removeLayer(CensusLayer);
#         CensusLayer = 0;
#       }
#     }
# );
#
#
# map.on('zoomend', function(e) {
#   if(CensusLayer != 0) {
#     CensusLayerBringToFront();
#   }
# });
#
# //200msecå¾ã£ã¦ãããCensusLayerãbringToFront
# function CensusLayerBringToFront() {
#   (async () => {
#     const sleep = (second) => new Promise(resolve => setTimeout(resolve, second * 200))
#     await sleep(1);
#     CensusLayer.bringToFront();
#   })()
# }
#
#
# //âââââââââââââââââââââââââââââââââââââââââââââââââ
# //  æ¤ç´¢
# //âââââââââââââââââââââââââââââââââââââââââââââââââ
# //æ¤ç´¢ãã¤ã¢ã­ã°ã®ç¨æ
# function CreatSearchDlg() {
#   var htmlTxt = "<table>";
#
#   htmlTxt = htmlTxt + "<tr><div id='CEN20'><font size='+2'>â </font>åºæ¬åºéçªå·ã§æ¤ç´¢</td></div><td></td><td></tr>"; //20231016 higa
#   htmlTxt = htmlTxt + "<tr><td><div id='CEN21'>åºæ¬åºéçªå·ã<br>ã</div></td><td><div id='CEN22'><input id='CENSUS2' type='text' value=''>ã<input id='CENSUS3' type='button' style='height:22px;' value='æ¤ç´¢' onclick='SearchDo()'><br>ä¾ï¼01110500010ãï¼11æ¡ã§å¥åï¼</div></td></tr>";
#   htmlTxt = htmlTxt + "<tr><td><font size='+2'>â </font>åºéå±æ§ã§æ¤ç´¢</td><td></td></tr>"; //20231016 higa
#   htmlTxt = htmlTxt + "<tr><td>é½éåºç</td><td><select id='KEN' onchange='KenSyubetuKanriChange()'><option value='0' hidden>é¸æãã¦ãã ãã</option>";
#   htmlTxt = htmlTxt + "<option value='01'>åæµ·é</option><option value='02'>éæ£®</option><option value='03'>å²©æ</option><option value='04'>å®®å</option><option value='05'>ç§ç°</option>";
#   htmlTxt = htmlTxt + "<option value='06'>å±±å½¢</option><option value='07'>ç¦å³¶</option><option value='08'>è¨å</option><option value='09'>æ æ¨</option><option value='10'>ç¾¤é¦¬</option>";
#   htmlTxt = htmlTxt + "<option value='11'>å¼ç</option><option value='12'>åè</option><option value='13'>æ±äº¬</option><option value='14'>ç¥å¥å·</option><option value='15'>æ°æ½</option>";
#   htmlTxt = htmlTxt + "<option value='16'>å¯å±±</option><option value='17'>ç³å·</option><option value='18'>ç¦äº</option><option value='19'>å±±æ¢¨</option><option value='20'>é·é</option>";
#   htmlTxt = htmlTxt + "<option value='21'>å²é</option><option value='22'>éå²¡</option><option value='23'>æç¥</option><option value='24'>ä¸é</option><option value='25'>æ»è³</option>";
#   htmlTxt = htmlTxt + "<option value='26'>äº¬é½</option><option value='27'>å¤§éª</option><option value='28'>åµåº«</option><option value='29'>å¥è¯</option><option value='30'>åæ­å±±</option>";
#   htmlTxt = htmlTxt + "<option value='31'>é³¥å</option><option value='32'>å³¶æ ¹</option><option value='33'>å²¡å±±</option><option value='34'>åºå³¶</option><option value='35'>å±±å£</option>";
#   htmlTxt = htmlTxt + "<option value='36'>å¾³å³¶</option><option value='37'>é¦å·</option><option value='38'>æåª</option><option value='39'>é«ç¥</option><option value='40'>ç¦å²¡</option>";
#   htmlTxt = htmlTxt + "<option value='41'>ä½è³</option><option value='42'>é·å´</option><option value='43'>çæ¬</option><option value='44'>å¤§å</option><option value='45'>å®®å´</option>";
#   htmlTxt = htmlTxt + "<option value='46'>é¹¿åå³¶</option><option value='47'>æ²ç¸</option></select></td></tr>";
#
#   htmlTxt = htmlTxt + "<tr><td>éè·¯ç¨®å¥</td><td><select id='SYUBETU' onchange='KenSyubetuKanriChange()'><option value='0'>æªé¸æ</option>";
#   var sJson = './censuspropex/syubetu.json';
#   $.ajaxSetup({async: false}); //åæå¦çã«åãæ¿ã
#   $.getJSON(sJson, function (json) {
#     $.each(json, function(idx, obj) {
#       htmlTxt = htmlTxt + "<option value='" + obj.éè·¯ç¨®å¥ + "'>" + obj.éè·¯ç¨®å¥ + "</option>";
#     });
#   });
#   htmlTxt = htmlTxt + "</select></td></tr>";
#
#   htmlTxt = htmlTxt + "<tr><td>éè·¯ç®¡çè</td><td><select id='KANRI' onchange='KenSyubetuKanriChange()'><option value='0'>æªé¸æ</option>";
#   sJson = './censuspropex/kanri.json';
#   $.getJSON(sJson, function (json) {
#     $.each(json, function(idx, obj) {
#       htmlTxt = htmlTxt + "<option value='" + obj.ç®¡çåºå + "'>" + obj.ç®¡çåºå + "</option>";
#     });
#   });
#   $.ajaxSetup({async: true}); //éåæã«æ»ã
#
#   htmlTxt = htmlTxt + "<tr><td>è·¯ç·å</td><td><select id='ROSEN' onchange='Search()'><option value='0'>é½éåºçãé¸æãã¦ãã ãã</option></select></td></tr>";
#   htmlTxt = htmlTxt + "</select></td></tr>";
#   htmlTxt = htmlTxt + "<tr><td>ã</td><td>ã</td></tr>";
#   htmlTxt = htmlTxt + "<tr><td><div id='CEN11'>åºæ¬åºéçªå·ã</div></td><td><div id='CEN12'><select id='CENSUS1'><option value='0' hidden>é¸æãã¦ãã ãã</option></select>ã<input id='CENSUS3' type='button' style='height:22px;' value='æ¤ç´¢' onclick='SearchDo()'></div></td></tr>";
#   htmlTxt = htmlTxt + "</table>";
#   document.getElementById("search_dlg").innerHTML = htmlTxt;
#
#   $('#SYUBETU').css('width',PROP.SEARCH_DIALOG_W - 180); //20231016 higa
#   $('#ROSEN').css('width',PROP.SEARCH_DIALOG_W - 180); //20231016 higa
#   $('#KANRI').css('width',PROP.SEARCH_DIALOG_W - 180); //20231016 higa
#   $('#CENSUS1').css('width',PROP.SEARCH_DIALOG_W - 220); //20231016 higa
#
#   document.getElementById('CEN11').style.display = 'none';
#   document.getElementById('CEN12').style.display = 'none';
#   document.getElementById('CEN20').style.display = 'inline'; //20231016 higa
#   document.getElementById('CEN21').style.display = 'inline';
#   document.getElementById('CEN22').style.display = 'inline';
# };
#
# //KenSyubetuKanriChange â çãéè·¯ç¨®å¥ããããã¯ç®¡çåºåã®é¸æãå¤æ´ãããã¨ã
# function KenSyubetuKanriChange() {
#
#   var sKen = document.getElementById("KEN").value; //å¿ãçã³ã¼ããå¥ã
#   var sSyubetu = document.getElementById("SYUBETU").value; //æªé¸æã¯'0'
#   var sKanri = document.getElementById("KANRI").value; //æªé¸æã¯'0'
#   var bSyubetu = false;
#   var bKanri = false;
#
#   if(sKen == '0') { //çé¸æãããã¦ããªãã¨ãã¯æããï¼20230606ï¼
#     return;
#   }
#
# //console.log("é½éåºç:" + sKen + "\néè·¯ç¨®å¥:" + sSyubetu + "\nç®¡çåºå:" + sKanri);
#
#   //è·¯ç·æ¤ç´¢
#   var sRosenJson = './censuspropex/' + sKen + 'rosen.json';
#   var aRosen = [];
#
#   $.ajaxSetup({async: false}); //åæå¦çã«åæ¿
#   $.getJSON(sRosenJson, function (rosenJson) {
#     $.each(rosenJson, function(idx, rosenObj) {
#       bSyubetu = false;
#       bKanri = false;
#
#       if(sSyubetu == '0' || rosenObj.éè·¯ç¨®å¥ == sSyubetu) { bSyubetu = true; }
#       if(sKanri == '0' || rosenObj.ç®¡çåºå == sKanri) { bKanri = true; }
#       if(bSyubetu && bKanri) {
#         var bHit = false;     //éè¤ãã§ãã¯
#         for (let i=0 ; i<aRosen.length; i++) {
#           if(aRosen[i] == rosenObj.è·¯ç·å) {
#             bHit = true;
#             break;
#           }
#         }
#         if(!bHit) {
#           aRosen.push(rosenObj.è·¯ç·å);
#         }
#       }
#     });
#   });
#
#   //è·¯ç· select option ç»é²
#   var select = document.getElementById('ROSEN');
#   var options = select.options
#
#   if (select.hasChildNodes()) {
#     while (select.childNodes.length > 0) {
#       select.removeChild(select.firstChild)
#     }
#   }
#
#   var option = document.createElement("option");
#   option.value = "0";
#   option.text = "æªé¸æ (" + String(aRosen.length) + ")";
#   select.appendChild(option);
#
#   aRosen.forEach(txt => {
#     var option = document.createElement("option");
#     option.value = txt;
#     option.text = txt;
#     select.appendChild(option);
#   });
#
#   $.ajaxSetup({async: true}); //éåæå¦çã«åæ¿
#
#   Search();
# }
#
# //ãªã»ãã
# function ResetSearchDlg() {
#   $("#KEN").val("0");
#   $("#SYUBETU").val("0");
#   $("#ROSEN").val("0");
#   $("#KANRI").val("0");
#   $("#CENSUS1").val("0");
#   $("#CENSUS2").val("");
#
#   var select = document.getElementById('ROSEN');
#   var options = select.options
#
#   if (select.hasChildNodes()) {
#     while (select.childNodes.length > 0) {
#       select.removeChild(select.firstChild)
#     }
#   }
#
#   var option = document.createElement("option");
#   option.value = "0";
#   option.text = "é½éåºçãé¸æãã¦ãã ãã";
#   option.hidden = true;
#   select.appendChild(option);
#   document.getElementById('CEN11').style.display = 'none';
#   document.getElementById('CEN12').style.display = 'none';
#   document.getElementById('CEN20').style.display = 'inline'; //20231016 higa
#   document.getElementById('CEN21').style.display = 'inline';
#   document.getElementById('CEN22').style.display = 'inline';
# }
#
# //search_dlg â #search_dlgå®ç¾©
# var search_dlg = $(function() {
#   $("#search_dlg").dialog({
#     title:"ãäº¤éèª¿æ»åºæ¬åºé æ¤ç´¢",
#     height: PROP.SEARCH_DIALOG_H , width: PROP.SEARCH_DIALOG_W,    //æ²è¼ãã¼ã¿ã®åå®¹å¦ä½ã§èª¿æ´å¿è¦ï¼ä¸çªé·ãè·¯ç·åã§èª¿æ´ï¼
#     buttons: [
# /*
#       {
#          text: 'æ¤ç´¢',
#          width:85,
#          height:25,
#          click: function() { SearchDo(); }
#       },
#       {
#          text: 'ã­ã£ã³ã»ã«',
#          width:90,
#          height:25,
#          click: function() { $(this).dialog("close"); }
#       },
# */
#       {
#          text:'ãªã»ãã',
#          width:75,
#          height:25,
#          click: function() { ResetSearchDlg(); }
#       },
#     ],
#
#     autoOpen: false,
#   });
# });
#
# //æ¤ç´¢ãã¿ã³
# function SearchBtn() {
#   if($("#search_dlg").dialog( "isOpen" )) {
#     $("#search_dlg").dialog( "close" );
#   } else {
#     ResetSearchDlg();
#     $("#search_dlg").dialog( "open" );
#     $("#search_dlg").dialog( "moveToTop" );
#   };
# }
#
# //ãã¡ã¤ã«ã®å­å¨ãã§ãã¯
# function is_file(fp){
#   var flg=null;
#   $.ajax({url:fp,cache:false,async:false}).done(function(data){flg=true;}).fail(function(jqXHR, textStatus, errorThrown){flg=false;});
#   return flg;
# }
#
# //ã»ã³ãµã¹ã®å­å¨ãã§ãã¯
# function CensusCheck(sCnsId){
#   var sKen = sCnsId.substr(0, 2);
#   var sJson = './censusprop/' + sKen + '/' + sCnsId + '.json';
#   if (is_file(sJson)) {
#     return true;
#   } else {
#     return false;
#   }
# }
#
# //SearchDo â æ¤ç´¢çµæã®å±æ§è¡¨ç¤º
# function SearchDo() {
# //console.log("1");
#   var sCnsId = $('#CENSUS2').val(); //ã¨ãã£ãããã¯ã¹
#   if (sCnsId != '') {
#     if(!CensusCheck(sCnsId)) {
#       alert(sCnsId + "ãã¿ã¤ããã¾ãã");
#       $('#CENSUS2').val('');
#       return;
#     }
#     $("#search_dlg").dialog( "close" );
#     CensusDo(sCnsId, true);
#     return;
#   }
#
# //console.log("2");
#
#   if($('[id=CENSUS1]').val() != ''){ //é¸æ
#     sCnsId = $('[id=CENSUS1] option:selected').text();
#     if (sCnsId != '' && CensusCheck(sCnsId)) {
#       $("#search_dlg").dialog( "close" );
#       CensusDo(sCnsId, true);
#       return;
#     }
#   }
# }
#
#
# //Search â æ¤ç´¢
# function Search() {
#   var sKen = document.getElementById("KEN").value; //å¿ãçã³ã¼ããå¥ã
#   var sSyubetu = document.getElementById("SYUBETU").value; //æªé¸æã¯'0'
#   var sRosen = document.getElementById("ROSEN").value; //æªé¸æã¯'0'
#   var sKanri = document.getElementById("KANRI").value; //æªé¸æã¯'0'
#   var bSyubetu = false;
#   var bRosen = false;
#   var bKanri = false;
#   var aCensus = [];
#
# //console.log("é½éåºç:" + sKen + "\néè·¯ç¨®å¥:" + sSyubetu + "\nè·¯ç·å:" + sRosen + "\nå½éå:" + sKokudo + "\nç®¡çåºå:" + sKanri);
#
#   if(sKen == '0') { //çé¸æãããã¦ããªãã¨ãã¯æããï¼20230606ï¼
#     return;
#   }
#
#   $.ajaxSetup({async: false}); //åæå¦çã«åæ¿
#
#   var sJson = './censuspropex/' + sKen + '.json';
#   $.getJSON(sJson, function (json) {
#     $.each(json, function(idx, obj) {
#       bSyubetu = false;
#       bRosen = false;
#       bKanri = false;
#
#       if(sSyubetu == '0' || obj.éè·¯ç¨®å¥ == sSyubetu) { bSyubetu = true; }
#       if(sRosen == '0' || obj.è·¯ç·å == sRosen) { bRosen = true; }
#       if(sKanri == '0' || obj.ç®¡çåºå == sKanri) { bKanri = true; }
#       if(bSyubetu && bRosen && bKanri) {
#         aCensus.push(obj.äº¤éèª¿æ»åºæ¬åºéçªå·);
#       }
#     });
#   });
#   $.ajaxSetup({async: true}); //éåæå¦çã«åæ¿
#
#   //çµãè¾¼ã¿æ¡ä»¶ã«ããã»ã³ãµã¹åè£ãªã¹ãä½æ
#   var select = document.getElementById('CENSUS1');
#   if (select.hasChildNodes()) {
#     while (select.childNodes.length > 0) {
#       select.removeChild(select.firstChild)
#     }
#   }
#
#   var option = document.createElement("option");
#   option.value = "0";
#   option.text = "é¸æãã¦ãã ãã (" + String(aCensus.length) + ")";
#   option.hidden = true;
#   select.appendChild(option);
#
#   aCensus.forEach(txt => {
#     var option = document.createElement("option");
#     option.value = txt;
#     option.text = txt;
#     select.appendChild(option);
#   });
#
#   document.getElementById('CEN11').style.display = 'inline';
#   document.getElementById('CEN12').style.display = 'inline';
#   document.getElementById('CEN20').style.display = 'none'; //20231016 higa
#   document.getElementById('CEN21').style.display = 'none';
#   document.getElementById('CEN22').style.display = 'none';
#   $("#CENSUS2").val("");
# }
#
# //URLããã·ã¥
# var hash = L.hash(map);
#
# //åæè¡¨ç¤ºï¼ã»ã³ãµã¹å¼æ°ãããã°ãåºéé¸æç¶æã«ãã¦ã¹ã³ã¼ããç§»åï¼
# window.onload = function(){
#   //æ¤ç´¢ãã¤ã¢ã­ã°åæå
#   CreatSearchDlg();
#
#   //ã»ã³ãµã¹å¼æ°
#   var urlParams = new URLSearchParams(window.location.search);
#   var census = urlParams.get('census')
# //var census = '47113500245';  //?census=47113500245ãä½ç½®æå®ã®å ´åã¯#13/26.5283/127.9762
#
#   CensusDo(census, true);
# };
#
# </script>
# <script type="text/javascript" src="/_Incapsula_Resource?SWJIYLWA=719d34d31c8e3a6e6fffd425f7e032f3&ns=2&cb=1910111456" async></script></body>
# </html>

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content, "html.parser")

# %%
results = soup.find(id="CEN11")
#print(results.prettify())

# %%
from selenium.webdriver import Firefox
from selenium.webdriver.firefox.options import Options
opts = Options()
#opts.set_headless()
#assert opts.headless  # Operating in headless mode
browser = Firefox(options=opts)
browser.get(URL)
# Out:
# The geckodriver version (0.32.0) detected in PATH at /usr/local/bin/geckodriver might not be compatible with the detected firefox version (126.0.1); currently, geckodriver 0.34.0 is recommended for firefox 126.*, so it is advised to delete the driver in PATH and retry
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-5-b3e8f7993870> in <module>
#       4 #opts.set_headless()
#       5 #assert opts.headless  # Operating in headless mode
# ----> 6 browser = Firefox(options=opts)
#       7 browser.get(URL)
#
# ~/opt/anaconda3/envs/takamatsu/lib/python3.8/site-packages/selenium/webdriver/firefox/webdriver.py in __init__(self, options, service, keep_alive)
#      69
#      70         try:
# ---> 71             super().__init__(command_executor=executor, options=options)
#      72         except Exception:
#      73             self.quit()
#
# ~/opt/anaconda3/envs/takamatsu/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in __init__(self, command_executor, keep_alive, file_detector, options)
#     210         self._authenticator_id = None
#     211         self.start_client()
# --> 212         self.start_session(capabilities)
#     213
#     214         self._websocket_connection = None
#
# ~/opt/anaconda3/envs/takamatsu/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in start_session(self, capabilities)
#     297
#     298         caps = _create_caps(capabilities)
# --> 299         response = self.execute(Command.NEW_SESSION, caps)["value"]
#     300         self.session_id = response.get("sessionId")
#     301         self.caps = response.get("capabilities")
#
# ~/opt/anaconda3/envs/takamatsu/lib/python3.8/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     352         response = self.command_executor.execute(driver_command, params)
#     353         if response:
# --> 354             self.error_handler.check_response(response)
#     355             response["value"] = self._unwrap_value(response.get("value", None))
#     356             return response
#
# ~/opt/anaconda3/envs/takamatsu/lib/python3.8/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     227                 alert_text = value["alert"].get("text")
#     228             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229         raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: Process unexpectedly closed with status 0

# %%
dir(opts)
# Out:
# ['BINARY_LOCATION_ERROR',
#  'KEY',
#  '__abstractmethods__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_arguments',
#  '_binary_location',
#  '_caps',
#  '_ignore_local_proxy',
#  '_preferences',
#  '_profile',
#  '_proxy',
#  'accept_insecure_certs',
#  'add_argument',
#  'arguments',
#  'binary',
#  'binary_location',
#  'browser_version',
#  'capabilities',
#  'default_capabilities',
#  'enable_bidi',
#  'enable_downloads',
#  'enable_mobile',
#  'ignore_local_proxy_environment_variables',
#  'log',
#  'mobile_options',
#  'page_load_strategy',
#  'platform_name',
#  'preferences',
#  'profile',
#  'proxy',
#  'set_capability',
#  'set_preference',
#  'set_window_rect',
#  'strict_file_interactability',
#  'timeouts',
#  'to_capabilities',
#  'unhandled_prompt_behavior',
#  'web_socket_url']
